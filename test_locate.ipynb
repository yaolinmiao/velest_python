# %%
import numpy as np
from inversion import *
from ray_tracer import *

# %%
# -------------------------------------------------------------
# 1.  True 1-D velocity model (unchanged)
# -------------------------------------------------------------
true_velocity_model = [
    {'top': 0.0, 'bottom': 2.0,  'velocity': 2.0},
    {'top': 2.0, 'bottom': 6.0,  'velocity': 3.0},
    {'top': 6.0, 'bottom': 15.0, 'velocity': 4},
]

# -------------------------------------------------------------
# 2.  Ten stations, 5 surface + 5 along a borehole (x=y=5 km)
# -------------------------------------------------------------
stations = [
    # ---- surface ring ---------------------------------------------------
    {'x':  0.0, 'y':  0.0, 'z': 0.0},
    {'x': 10.0, 'y':  0.0, 'z': 0.0},
    {'x':  0.0, 'y': 10.0, 'z': 0.0},
    {'x': 10.0, 'y': 10.0, 'z': 0.0},
    {'x':  5.0, 'y':  5.0, 'z': 0.0},   # top of borehole

    # ---- down-hole receivers -------------------------------------------
    {'x':  5.0, 'y':  5.0, 'z': 1.0},   # inside layer 1
    {'x':  5.0, 'y':  5.0, 'z': 3.0},   # crosses into layer 2
    {'x':  5.0, 'y':  5.0, 'z': 5.0},
    {'x':  5.0, 'y':  5.0, 'z': 7.0},   # samples top of layer 3
    {'x':  5.0, 'y':  5.0, 'z': 9.0},   # deepest receiver
]

# -------------------------------------------------------------
# 3.  True event (unchanged)
# -------------------------------------------------------------
true_event = {'x': 1.8, 'y': 2.4, 'z': 3.8, 't0': 0.5}

# -------------------------------------------------------------
# 4.  Synthetic arrival times + ray-parameter printout
# -------------------------------------------------------------
true_arrivals = []
for sta in stations:
    t_calc, _, p = trace_ray(true_event, sta, true_velocity_model)
    true_arrivals.append(t_calc + true_event['t0'])
    print(f"Station ({sta['x']:4.1f},{sta['y']:4.1f},{sta['z']:4.1f})  p = {p:7.4f} s/km")

# -------------------------------------------------------------
# 5.  Add Gaussian noise  (σ = 0.01 s)
# -------------------------------------------------------------
np.random.seed(42)
observed_arrivals = [t + np.random.normal(0, 0.01) for t in true_arrivals]

# -------------------------------------------------------------
# 6.  Initial guesses (slightly off)
# -------------------------------------------------------------
initial_event = {'x': 3.0, 'y': 3.0, 'z': 3.5, 't0': 0.4}

# -------------------------------------------------------------
# 7.  Run the joint inversion
# -------------------------------------------------------------
updated_event, rms = invert_event(
    event=initial_event,
    stations=stations,
    picks=observed_arrivals,
    velocity_model=true_velocity_model,   # keep the layers fixed
    max_iter=500,
    tol=0.0001,
    differential=False   # or True if you want to eliminate t0
)

# -------------------------------------------------------------
# 8.  Report results
# -------------------------------------------------------------
print("\n=== True Event ===")
print(true_event)

print("\n=== Estimated Event ===")
print(updated_event)
# Out:
# Station ( 0.0, 0.0, 0.0)  p =  0.2417 s/km
# Station (10.0, 0.0, 0.0)  p =  0.3224 s/km
# Station ( 0.0,10.0, 0.0)  p =  0.3199 s/km
# Station (10.0,10.0, 0.0)  p =  0.3274 s/km
# Station ( 5.0, 5.0, 0.0)  p =  0.2796 s/km
# Station ( 5.0, 5.0, 1.0)  p =  0.2945 s/km
# Station ( 5.0, 5.0, 3.0)  p =  0.3272 s/km
# Station ( 5.0, 5.0, 5.0)  p =  0.3201 s/km
# Station ( 5.0, 5.0, 7.0)  p =  0.2257 s/km
# Station ( 5.0, 5.0, 9.0)  p =  0.1709 s/km
# Iter 01  RMS=0.4167  |Δm|=2.00e-02
# Iter 02  RMS=0.4033  |Δm|=2.00e-02
# Iter 03  RMS=0.3917  |Δm|=2.00e-02
# Iter 04  RMS=0.3801  |Δm|=2.00e-02
# Iter 05  RMS=0.3688  |Δm|=2.00e-02
# Iter 06  RMS=0.3567  |Δm|=2.00e-02
# Iter 07  RMS=0.3452  |Δm|=2.00e-02
# Iter 08  RMS=0.3334  |Δm|=2.00e-02
# Iter 09  RMS=0.3220  |Δm|=2.00e-02
# Iter 10  RMS=0.3109  |Δm|=2.00e-02
# Iter 11  RMS=0.3000  |Δm|=2.00e-02
# Iter 12  RMS=0.2916  |Δm|=2.00e-02
# Iter 13  RMS=0.2800  |Δm|=2.00e-02
# Iter 14  RMS=0.2699  |Δm|=2.00e-02
# Iter 15  RMS=0.2594  |Δm|=1.76e-02
# Iter 16  RMS=0.2572  |Δm|=1.80e-02
# Iter 17  RMS=0.2473  |Δm|=2.00e-02
# Iter 18  RMS=0.2371  |Δm|=1.98e-02
# Iter 19  RMS=0.2409  |Δm|=1.43e-02
# Iter 20  RMS=0.2376  |Δm|=1.47e-02
# Iter 21  RMS=0.2370  |Δm|=2.00e-02
# Iter 22  RMS=0.2292  |Δm|=2.00e-02
# Iter 23  RMS=0.2230  |Δm|=2.00e-02
# Iter 24  RMS=0.2156  |Δm|=2.00e-02
# Iter 25  RMS=0.2060  |Δm|=1.91e-02
# Iter 26  RMS=0.1977  |Δm|=2.00e-02
# Iter 27  RMS=0.1992  |Δm|=2.00e-02
# Iter 28  RMS=0.2023  |Δm|=2.00e-02
# Iter 29  RMS=0.1958  |Δm|=2.00e-02
# Iter 30  RMS=0.1870  |Δm|=2.00e-02
# Iter 31  RMS=0.1886  |Δm|=2.00e-02
# Iter 32  RMS=0.1804  |Δm|=2.00e-02
# Iter 33  RMS=0.1741  |Δm|=2.00e-02
# Iter 34  RMS=0.1766  |Δm|=2.00e-02
# Iter 35  RMS=0.1777  |Δm|=2.00e-02
# Iter 36  RMS=0.1724  |Δm|=2.00e-02
# Iter 37  RMS=0.1738  |Δm|=2.00e-02
# Iter 38  RMS=0.1767  |Δm|=2.00e-02
# Iter 39  RMS=0.1710  |Δm|=2.00e-02
# Iter 40  RMS=0.1723  |Δm|=1.76e-02
# Iter 41  RMS=0.1700  |Δm|=2.00e-02
# Iter 42  RMS=0.1726  |Δm|=2.00e-02
# Iter 43  RMS=0.1753  |Δm|=1.76e-02
# Iter 44  RMS=0.1688  |Δm|=1.84e-02
# Iter 45  RMS=0.1585  |Δm|=2.00e-02
# Iter 46  RMS=0.1609  |Δm|=2.00e-02
# Iter 47  RMS=0.1639  |Δm|=2.00e-02
# Iter 48  RMS=0.1541  |Δm|=2.00e-02
# Iter 49  RMS=0.1449  |Δm|=2.00e-02
# Iter 50  RMS=0.1397  |Δm|=1.86e-02
# Iter 51  RMS=0.1414  |Δm|=2.00e-02
# Iter 52  RMS=0.1441  |Δm|=2.00e-02
# Iter 53  RMS=0.1375  |Δm|=2.00e-02
# Iter 54  RMS=0.1396  |Δm|=2.00e-02
# Iter 55  RMS=0.1429  |Δm|=2.00e-02
# Iter 56  RMS=0.1447  |Δm|=1.84e-02
# Iter 57  RMS=0.1380  |Δm|=2.00e-02
# Iter 58  RMS=0.1406  |Δm|=1.76e-02
# Iter 59  RMS=0.1311  |Δm|=2.00e-02
# Iter 60  RMS=0.1346  |Δm|=1.95e-02
# Iter 61  RMS=0.1365  |Δm|=2.00e-02
# Iter 62  RMS=0.1269  |Δm|=2.00e-02
# Iter 63  RMS=0.1305  |Δm|=2.00e-02
# Iter 64  RMS=0.1334  |Δm|=2.00e-02
# Iter 65  RMS=0.1376  |Δm|=2.00e-02
# Iter 66  RMS=0.1291  |Δm|=1.84e-02
# Iter 67  RMS=0.1299  |Δm|=2.00e-02
# Iter 68  RMS=0.1201  |Δm|=2.00e-02
# Iter 69  RMS=0.1233  |Δm|=1.86e-02
# Iter 70  RMS=0.1153  |Δm|=2.00e-02
# Iter 71  RMS=0.1187  |Δm|=1.48e-02
# Iter 72  RMS=0.1138  |Δm|=1.75e-02
# Iter 73  RMS=0.1083  |Δm|=2.00e-02
# Iter 74  RMS=0.1011  |Δm|=2.00e-02
# Iter 75  RMS=0.1047  |Δm|=2.00e-02
# Iter 76  RMS=0.0947  |Δm|=2.00e-02
# Iter 77  RMS=0.0881  |Δm|=2.00e-02
# Iter 78  RMS=0.0899  |Δm|=2.00e-02
# Iter 79  RMS=0.0937  |Δm|=1.77e-02
# Iter 80  RMS=0.0875  |Δm|=2.00e-02
# Iter 81  RMS=0.0902  |Δm|=2.00e-02
# Iter 82  RMS=0.0814  |Δm|=2.00e-02
# Iter 83  RMS=0.0842  |Δm|=1.81e-02
# Iter 84  RMS=0.0851  |Δm|=1.74e-02
# Iter 85  RMS=0.0829  |Δm|=1.79e-02
# Iter 86  RMS=0.0829  |Δm|=2.00e-02
# Iter 87  RMS=0.0762  |Δm|=1.47e-02
# Iter 88  RMS=0.0751  |Δm|=2.00e-02
# Iter 89  RMS=0.0790  |Δm|=1.53e-02
# Iter 90  RMS=0.0743  |Δm|=1.89e-02
# Iter 91  RMS=0.0766  |Δm|=2.00e-02
# Iter 92  RMS=0.0807  |Δm|=2.00e-02
# Iter 93  RMS=0.0701  |Δm|=1.77e-02
# Iter 94  RMS=0.0624  |Δm|=1.87e-02
# Iter 95  RMS=0.0552  |Δm|=1.74e-02
# Iter 96  RMS=0.0525  |Δm|=2.00e-02
# Iter 97  RMS=0.0542  |Δm|=1.75e-02
# Iter 98  RMS=0.0577  |Δm|=2.00e-02
# Iter 99  RMS=0.0492  |Δm|=1.46e-02
# Iter 100  RMS=0.0536  |Δm|=1.49e-02
# Iter 101  RMS=0.0522  |Δm|=1.81e-02
# Iter 102  RMS=0.0465  |Δm|=1.81e-02
# Iter 103  RMS=0.0396  |Δm|=1.55e-02
# Iter 104  RMS=0.0378  |Δm|=1.81e-02
# Iter 105  RMS=0.0338  |Δm|=1.33e-02
# Iter 106  RMS=0.0344  |Δm|=1.63e-02
# Iter 107  RMS=0.0360  |Δm|=1.73e-02
# Iter 108  RMS=0.0317  |Δm|=1.73e-02
# Iter 109  RMS=0.0240  |Δm|=1.57e-02
# Iter 110  RMS=0.0240  |Δm|=2.00e-02
# Iter 111  RMS=0.0190  |Δm|=1.28e-02
# Iter 112  RMS=0.0185  |Δm|=1.89e-02
# Iter 113  RMS=0.0196  |Δm|=1.45e-02
# Iter 114  RMS=0.0152  |Δm|=1.42e-02
# Iter 115  RMS=0.0127  |Δm|=1.43e-02
# Iter 116  RMS=0.0134  |Δm|=1.03e-02
# Iter 117  RMS=0.0100  |Δm|=1.48e-02
# Iter 118  RMS=0.0095  |Δm|=1.43e-02
# Iter 119  RMS=0.0083  |Δm|=1.00e-02
# Iter 120  RMS=0.0073  |Δm|=1.37e-02
# Iter 121  RMS=0.0072  |Δm|=1.07e-02
# Iter 122  RMS=0.0068  |Δm|=1.32e-02
# Iter 123  RMS=0.0062  |Δm|=6.44e-03
# Iter 124  RMS=0.0060  |Δm|=5.92e-03
# Iter 125  RMS=0.0066  |Δm|=4.53e-03
# Iter 126  RMS=0.0058  |Δm|=1.16e-02
# Iter 127  RMS=0.0066  |Δm|=1.41e-02
# Iter 128  RMS=0.0066  |Δm|=1.76e-02
# Iter 129  RMS=0.0066  |Δm|=1.08e-02
# Iter 130  RMS=0.0067  |Δm|=1.01e-02
# Iter 131  RMS=0.0071  |Δm|=1.75e-02
# Iter 132  RMS=0.0064  |Δm|=1.08e-02
# Iter 133  RMS=0.0067  |Δm|=6.56e-03
# Iter 134  RMS=0.0071  |Δm|=1.09e-02
# Iter 135  RMS=0.0074  |Δm|=1.66e-02
# Iter 136  RMS=0.0074  |Δm|=1.07e-02
# Iter 137  RMS=0.0070  |Δm|=1.43e-02
# Iter 138  RMS=0.0063  |Δm|=4.37e-03
# Iter 139  RMS=0.0059  |Δm|=5.70e-03
# Iter 140  RMS=0.0060  |Δm|=1.75e-03
# Iter 141  RMS=0.0062  |Δm|=7.53e-04
# Iter 142  RMS=0.0063  |Δm|=1.25e-02
# Iter 143  RMS=0.0075  |Δm|=1.45e-02
# Iter 144  RMS=0.0072  |Δm|=1.21e-02
# Iter 145  RMS=0.0066  |Δm|=9.02e-03
# Iter 146  RMS=0.0069  |Δm|=1.09e-02
# Iter 147  RMS=0.0063  |Δm|=1.06e-02
# Iter 148  RMS=0.0063  |Δm|=1.08e-02
# Iter 149  RMS=0.0058  |Δm|=1.02e-02
# Iter 150  RMS=0.0059  |Δm|=1.26e-02
# Iter 151  RMS=0.0067  |Δm|=1.16e-02
# Iter 152  RMS=0.0066  |Δm|=1.31e-02
# Iter 153  RMS=0.0064  |Δm|=9.39e-03
# Iter 154  RMS=0.0068  |Δm|=1.17e-02
# Iter 155  RMS=0.0060  |Δm|=1.27e-02
# Iter 156  RMS=0.0060  |Δm|=7.19e-03
# Iter 157  RMS=0.0066  |Δm|=1.19e-02
# Iter 158  RMS=0.0061  |Δm|=1.31e-02
# Iter 159  RMS=0.0071  |Δm|=6.04e-03
# Iter 160  RMS=0.0066  |Δm|=8.93e-03
# Iter 161  RMS=0.0057  |Δm|=1.20e-02
# Iter 162  RMS=0.0066  |Δm|=1.07e-02
# Iter 163  RMS=0.0064  |Δm|=7.53e-03
# Iter 164  RMS=0.0063  |Δm|=1.33e-02
# Iter 165  RMS=0.0067  |Δm|=1.14e-02
# Iter 166  RMS=0.0063  |Δm|=3.77e-03
# Iter 167  RMS=0.0066  |Δm|=1.32e-02
# Iter 168  RMS=0.0069  |Δm|=9.19e-03
# Iter 169  RMS=0.0069  |Δm|=1.49e-02
# Iter 170  RMS=0.0068  |Δm|=1.19e-02
# Iter 171  RMS=0.0068  |Δm|=1.37e-02
# Iter 172  RMS=0.0062  |Δm|=1.23e-02
# Iter 173  RMS=0.0062  |Δm|=7.26e-03
# Iter 174  RMS=0.0061  |Δm|=1.46e-02
# Iter 175  RMS=0.0068  |Δm|=1.44e-02
# Iter 176  RMS=0.0067  |Δm|=9.59e-03
# Iter 177  RMS=0.0066  |Δm|=5.83e-03
# Iter 178  RMS=0.0059  |Δm|=1.31e-02
# Iter 179  RMS=0.0066  |Δm|=1.04e-02
# Iter 180  RMS=0.0061  |Δm|=1.56e-02
# Iter 181  RMS=0.0063  |Δm|=7.85e-03
# Iter 182  RMS=0.0065  |Δm|=1.17e-02
# Iter 183  RMS=0.0071  |Δm|=1.35e-02
# Iter 184  RMS=0.0068  |Δm|=1.54e-03
# Iter 185  RMS=0.0066  |Δm|=1.22e-02
# Iter 186  RMS=0.0067  |Δm|=5.87e-03
# Iter 187  RMS=0.0067  |Δm|=1.68e-02
# Iter 188  RMS=0.0062  |Δm|=6.41e-03
# Iter 189  RMS=0.0067  |Δm|=1.44e-02
# Iter 190  RMS=0.0069  |Δm|=1.24e-02
# Iter 191  RMS=0.0069  |Δm|=6.28e-03
# Iter 192  RMS=0.0073  |Δm|=1.51e-03
# Iter 193  RMS=0.0072  |Δm|=1.77e-02
# Iter 194  RMS=0.0075  |Δm|=1.10e-02
# Iter 195  RMS=0.0075  |Δm|=1.05e-02
# Iter 196  RMS=0.0068  |Δm|=1.42e-02
# Iter 197  RMS=0.0072  |Δm|=1.42e-02
# Iter 198  RMS=0.0063  |Δm|=1.32e-02
# Iter 199  RMS=0.0064  |Δm|=1.09e-02
# Iter 200  RMS=0.0064  |Δm|=8.55e-03
# Iter 201  RMS=0.0061  |Δm|=1.16e-02
# Iter 202  RMS=0.0060  |Δm|=1.07e-02
# Iter 203  RMS=0.0067  |Δm|=1.52e-02
# Iter 204  RMS=0.0062  |Δm|=9.34e-03
# Iter 205  RMS=0.0061  |Δm|=1.09e-02
# Iter 206  RMS=0.0067  |Δm|=8.63e-03
# Iter 207  RMS=0.0064  |Δm|=1.09e-02
# Iter 208  RMS=0.0066  |Δm|=4.17e-03
# Iter 209  RMS=0.0063  |Δm|=1.44e-02
# Iter 210  RMS=0.0067  |Δm|=1.06e-02
# Iter 211  RMS=0.0067  |Δm|=1.10e-02
# Iter 212  RMS=0.0059  |Δm|=1.08e-02
# Iter 213  RMS=0.0061  |Δm|=5.94e-03
# Iter 214  RMS=0.0068  |Δm|=1.31e-02
# Iter 215  RMS=0.0064  |Δm|=5.03e-03
# Iter 216  RMS=0.0067  |Δm|=1.33e-02
# Iter 217  RMS=0.0065  |Δm|=1.60e-02
# Iter 218  RMS=0.0073  |Δm|=5.91e-03
# Iter 219  RMS=0.0070  |Δm|=1.45e-02
# Iter 220  RMS=0.0062  |Δm|=1.44e-02
# Iter 221  RMS=0.0062  |Δm|=5.60e-03
# Iter 222  RMS=0.0068  |Δm|=1.24e-02
# Iter 223  RMS=0.0070  |Δm|=1.50e-02
# Iter 224  RMS=0.0059  |Δm|=1.02e-02
# Iter 225  RMS=0.0066  |Δm|=6.22e-03
# Iter 226  RMS=0.0059  |Δm|=1.09e-02
# Iter 227  RMS=0.0066  |Δm|=5.29e-03
# Iter 228  RMS=0.0058  |Δm|=8.16e-03
# Iter 229  RMS=0.0062  |Δm|=6.85e-03
# Iter 230  RMS=0.0063  |Δm|=7.36e-03
# Iter 231  RMS=0.0061  |Δm|=8.54e-03
# Iter 232  RMS=0.0061  |Δm|=1.42e-02
# Iter 233  RMS=0.0068  |Δm|=8.69e-03
# Iter 234  RMS=0.0064  |Δm|=1.19e-02
# Iter 235  RMS=0.0061  |Δm|=5.23e-03
# Iter 236  RMS=0.0052  |Δm|=5.35e-03
# Iter 237  RMS=0.0062  |Δm|=9.86e-03
# Iter 238  RMS=0.0056  |Δm|=1.19e-02
# Iter 239  RMS=0.0063  |Δm|=8.83e-03
# Iter 240  RMS=0.0063  |Δm|=1.05e-02
# Iter 241  RMS=0.0059  |Δm|=5.15e-03
# Iter 242  RMS=0.0059  |Δm|=1.60e-02
# Iter 243  RMS=0.0063  |Δm|=1.49e-02
# Iter 244  RMS=0.0063  |Δm|=1.41e-02
# Iter 245  RMS=0.0068  |Δm|=1.11e-02
# Iter 246  RMS=0.0063  |Δm|=3.45e-03
# Iter 247  RMS=0.0067  |Δm|=5.51e-03
# Iter 248  RMS=0.0069  |Δm|=1.31e-02
# Iter 249  RMS=0.0061  |Δm|=6.03e-03
# Iter 250  RMS=0.0060  |Δm|=1.24e-02
# Iter 251  RMS=0.0064  |Δm|=1.53e-02
# Iter 252  RMS=0.0066  |Δm|=1.55e-02
# Iter 253  RMS=0.0061  |Δm|=1.12e-02
# Iter 254  RMS=0.0062  |Δm|=6.64e-03
# Iter 255  RMS=0.0067  |Δm|=1.13e-02
# Iter 256  RMS=0.0064  |Δm|=9.33e-03
# Iter 257  RMS=0.0070  |Δm|=1.50e-02
# Iter 258  RMS=0.0061  |Δm|=7.82e-03
# Iter 259  RMS=0.0067  |Δm|=1.58e-02
# Iter 260  RMS=0.0062  |Δm|=9.85e-03
# Iter 261  RMS=0.0064  |Δm|=9.83e-03
# Iter 262  RMS=0.0068  |Δm|=1.03e-02
# Iter 263  RMS=0.0072  |Δm|=1.56e-02
# Iter 264  RMS=0.0063  |Δm|=1.10e-02
# Iter 265  RMS=0.0065  |Δm|=9.71e-03
# Iter 266  RMS=0.0068  |Δm|=6.75e-03
# Iter 267  RMS=0.0064  |Δm|=4.85e-03
# Iter 268  RMS=0.0070  |Δm|=7.91e-03
# Iter 269  RMS=0.0066  |Δm|=1.29e-02
# Iter 270  RMS=0.0065  |Δm|=5.70e-03
# Iter 271  RMS=0.0063  |Δm|=1.10e-02
# Iter 272  RMS=0.0061  |Δm|=1.56e-02
# Iter 273  RMS=0.0063  |Δm|=1.49e-02
# Iter 274  RMS=0.0067  |Δm|=1.43e-02
# Iter 275  RMS=0.0056  |Δm|=1.34e-02
# Iter 276  RMS=0.0070  |Δm|=7.44e-03
# Iter 277  RMS=0.0061  |Δm|=1.07e-02
# Iter 278  RMS=0.0067  |Δm|=9.53e-03
# Iter 279  RMS=0.0059  |Δm|=1.33e-02
# Iter 280  RMS=0.0063  |Δm|=4.65e-03
# Iter 281  RMS=0.0067  |Δm|=7.59e-03
# Iter 282  RMS=0.0062  |Δm|=9.01e-03
# Iter 283  RMS=0.0068  |Δm|=1.30e-02
# Iter 284  RMS=0.0063  |Δm|=1.02e-02
# Iter 285  RMS=0.0063  |Δm|=1.42e-02
# Iter 286  RMS=0.0062  |Δm|=1.13e-02
# Iter 287  RMS=0.0062  |Δm|=8.17e-03
# Iter 288  RMS=0.0066  |Δm|=1.04e-02
# Iter 289  RMS=0.0061  |Δm|=2.96e-03
# Iter 290  RMS=0.0063  |Δm|=7.23e-03
# Iter 291  RMS=0.0067  |Δm|=9.11e-03
# Iter 292  RMS=0.0065  |Δm|=8.39e-03
# Iter 293  RMS=0.0059  |Δm|=1.01e-02
# Iter 294  RMS=0.0065  |Δm|=1.01e-02
# Iter 295  RMS=0.0061  |Δm|=7.49e-03
# Iter 296  RMS=0.0069  |Δm|=1.01e-02
# Iter 297  RMS=0.0066  |Δm|=4.07e-03
# Iter 298  RMS=0.0064  |Δm|=5.21e-03
# Iter 299  RMS=0.0061  |Δm|=1.57e-02
# Iter 300  RMS=0.0070  |Δm|=1.29e-02
# Iter 301  RMS=0.0069  |Δm|=1.79e-02
# Iter 302  RMS=0.0073  |Δm|=9.68e-03
# Iter 303  RMS=0.0072  |Δm|=1.04e-02
# Iter 304  RMS=0.0078  |Δm|=1.42e-02
# Iter 305  RMS=0.0079  |Δm|=1.14e-02
# Iter 306  RMS=0.0069  |Δm|=1.63e-02
# Iter 307  RMS=0.0067  |Δm|=1.58e-02
# Iter 308  RMS=0.0064  |Δm|=6.47e-03
# Iter 309  RMS=0.0068  |Δm|=7.97e-03
# Iter 310  RMS=0.0063  |Δm|=8.10e-03
# Iter 311  RMS=0.0062  |Δm|=1.31e-02
# Iter 312  RMS=0.0061  |Δm|=1.17e-02
# Iter 313  RMS=0.0062  |Δm|=8.71e-03
# Iter 314  RMS=0.0068  |Δm|=4.27e-03
# Iter 315  RMS=0.0065  |Δm|=1.23e-02
# Iter 316  RMS=0.0061  |Δm|=6.75e-03
# Iter 317  RMS=0.0066  |Δm|=6.15e-03
# Iter 318  RMS=0.0068  |Δm|=3.82e-03
# Iter 319  RMS=0.0064  |Δm|=1.45e-02
# Iter 320  RMS=0.0065  |Δm|=1.00e-02
# Iter 321  RMS=0.0059  |Δm|=4.67e-03
# Iter 322  RMS=0.0062  |Δm|=1.19e-02
# Iter 323  RMS=0.0060  |Δm|=6.97e-03
# Iter 324  RMS=0.0068  |Δm|=1.51e-02
# Iter 325  RMS=0.0066  |Δm|=1.10e-02
# Iter 326  RMS=0.0057  |Δm|=1.03e-02
# Iter 327  RMS=0.0064  |Δm|=8.00e-03
# Iter 328  RMS=0.0067  |Δm|=1.27e-02
# Iter 329  RMS=0.0063  |Δm|=1.12e-02
# Iter 330  RMS=0.0064  |Δm|=1.12e-02
# Iter 331  RMS=0.0062  |Δm|=1.10e-02
# Iter 332  RMS=0.0068  |Δm|=1.19e-02
# Iter 333  RMS=0.0062  |Δm|=1.21e-02
# Iter 334  RMS=0.0066  |Δm|=5.22e-03
# Iter 335  RMS=0.0064  |Δm|=1.21e-02
# Iter 336  RMS=0.0059  |Δm|=1.17e-02
# Iter 337  RMS=0.0062  |Δm|=1.13e-02
# Iter 338  RMS=0.0062  |Δm|=4.01e-03
# Iter 339  RMS=0.0061  |Δm|=9.27e-03
# Iter 340  RMS=0.0066  |Δm|=9.65e-03
# Iter 341  RMS=0.0064  |Δm|=1.75e-02
# Iter 342  RMS=0.0068  |Δm|=6.22e-03
# Iter 343  RMS=0.0065  |Δm|=1.12e-02
# Iter 344  RMS=0.0064  |Δm|=9.28e-03
# Iter 345  RMS=0.0064  |Δm|=1.17e-02
# Iter 346  RMS=0.0062  |Δm|=8.98e-03
# Iter 347  RMS=0.0064  |Δm|=1.09e-02
# Iter 348  RMS=0.0065  |Δm|=8.74e-03
# Iter 349  RMS=0.0065  |Δm|=1.11e-02
# Iter 350  RMS=0.0062  |Δm|=1.16e-02
# Iter 351  RMS=0.0065  |Δm|=8.32e-03
# Iter 352  RMS=0.0063  |Δm|=1.12e-02
# Iter 353  RMS=0.0064  |Δm|=4.89e-03
# Iter 354  RMS=0.0060  |Δm|=1.10e-02
# Iter 355  RMS=0.0065  |Δm|=1.20e-02
# Iter 356  RMS=0.0070  |Δm|=1.24e-02
# Iter 357  RMS=0.0066  |Δm|=5.80e-03
# Iter 358  RMS=0.0066  |Δm|=6.82e-03
# Iter 359  RMS=0.0064  |Δm|=3.33e-03
# Iter 360  RMS=0.0064  |Δm|=1.32e-02
# Iter 361  RMS=0.0061  |Δm|=5.13e-03
# Iter 362  RMS=0.0071  |Δm|=1.03e-02
# Iter 363  RMS=0.0069  |Δm|=1.34e-02
# Iter 364  RMS=0.0070  |Δm|=6.27e-03
# Iter 365  RMS=0.0073  |Δm|=1.42e-02
# Iter 366  RMS=0.0064  |Δm|=5.05e-03
# Iter 367  RMS=0.0064  |Δm|=1.19e-02
# Iter 368  RMS=0.0061  |Δm|=8.17e-03
# Iter 369  RMS=0.0064  |Δm|=1.04e-02
# Iter 370  RMS=0.0067  |Δm|=1.21e-02
# Iter 371  RMS=0.0068  |Δm|=1.43e-02
# Iter 372  RMS=0.0065  |Δm|=3.72e-03
# Iter 373  RMS=0.0069  |Δm|=1.30e-02
# Iter 374  RMS=0.0067  |Δm|=1.46e-02
# Iter 375  RMS=0.0070  |Δm|=1.58e-02
# Iter 376  RMS=0.0062  |Δm|=1.73e-02
# Iter 377  RMS=0.0067  |Δm|=1.01e-02
# Iter 378  RMS=0.0067  |Δm|=1.17e-02
# Iter 379  RMS=0.0068  |Δm|=1.19e-02
# Iter 380  RMS=0.0066  |Δm|=1.23e-02
# Iter 381  RMS=0.0060  |Δm|=1.08e-02
# Iter 382  RMS=0.0064  |Δm|=1.76e-02
# Iter 383  RMS=0.0070  |Δm|=8.71e-03
# Iter 384  RMS=0.0064  |Δm|=1.24e-02
# Iter 385  RMS=0.0068  |Δm|=1.33e-02
# Iter 386  RMS=0.0064  |Δm|=1.24e-02
# Iter 387  RMS=0.0082  |Δm|=4.49e-03
# Iter 388  RMS=0.0072  |Δm|=7.46e-03
# Iter 389  RMS=0.0064  |Δm|=1.14e-02
# Iter 390  RMS=0.0069  |Δm|=1.35e-02
# Iter 391  RMS=0.0066  |Δm|=9.08e-03
# Iter 392  RMS=0.0067  |Δm|=1.74e-02
# Iter 393  RMS=0.0079  |Δm|=1.15e-02
# Iter 394  RMS=0.0063  |Δm|=7.04e-03
# Iter 395  RMS=0.0063  |Δm|=6.57e-03
# Iter 396  RMS=0.0069  |Δm|=6.67e-03
# Iter 397  RMS=0.0067  |Δm|=1.01e-02
# Iter 398  RMS=0.0062  |Δm|=1.05e-02
# Iter 399  RMS=0.0062  |Δm|=8.68e-03
# Iter 400  RMS=0.0066  |Δm|=1.09e-02
# Iter 401  RMS=0.0060  |Δm|=1.03e-02
# Iter 402  RMS=0.0063  |Δm|=5.34e-03
# Iter 403  RMS=0.0062  |Δm|=1.60e-02
# Iter 404  RMS=0.0082  |Δm|=7.10e-03
# Iter 405  RMS=0.0068  |Δm|=1.23e-02
# Iter 406  RMS=0.0064  |Δm|=1.05e-02
# Iter 407  RMS=0.0058  |Δm|=7.61e-04
# Iter 408  RMS=0.0059  |Δm|=8.17e-03
# Iter 409  RMS=0.0069  |Δm|=1.42e-03
# Iter 410  RMS=0.0059  |Δm|=8.88e-03
# Iter 411  RMS=0.0062  |Δm|=1.22e-02
# Iter 412  RMS=0.0072  |Δm|=1.02e-02
# Iter 413  RMS=0.0066  |Δm|=5.91e-03
# Iter 414  RMS=0.0068  |Δm|=9.55e-03
# Iter 415  RMS=0.0062  |Δm|=1.69e-02
# Iter 416  RMS=0.0064  |Δm|=9.13e-03
# Iter 417  RMS=0.0063  |Δm|=4.12e-03
# Iter 418  RMS=0.0064  |Δm|=4.04e-03
# Iter 419  RMS=0.0064  |Δm|=1.06e-02
# Iter 420  RMS=0.0061  |Δm|=1.10e-02
# Iter 421  RMS=0.0063  |Δm|=1.22e-02
# Iter 422  RMS=0.0070  |Δm|=1.55e-02
# Iter 423  RMS=0.0063  |Δm|=1.16e-02
# Iter 424  RMS=0.0062  |Δm|=1.18e-02
# Iter 425  RMS=0.0063  |Δm|=4.47e-03
# Iter 426  RMS=0.0062  |Δm|=7.48e-03
# Iter 427  RMS=0.0062  |Δm|=1.34e-02
# Iter 428  RMS=0.0068  |Δm|=1.38e-02
# Iter 429  RMS=0.0061  |Δm|=2.32e-03
# Iter 430  RMS=0.0059  |Δm|=1.61e-03
# Iter 431  RMS=0.0060  |Δm|=1.22e-02
# Iter 432  RMS=0.0070  |Δm|=1.52e-02
# Iter 433  RMS=0.0067  |Δm|=3.98e-03
# Iter 434  RMS=0.0064  |Δm|=1.00e-02
# Iter 435  RMS=0.0067  |Δm|=6.43e-03
# Iter 436  RMS=0.0068  |Δm|=3.13e-03
# Iter 437  RMS=0.0065  |Δm|=1.66e-02
# Iter 438  RMS=0.0064  |Δm|=6.81e-03
# Iter 439  RMS=0.0066  |Δm|=5.89e-03
# Iter 440  RMS=0.0063  |Δm|=1.22e-02
# Iter 441  RMS=0.0063  |Δm|=1.23e-02
# Iter 442  RMS=0.0065  |Δm|=3.54e-03
# Iter 443  RMS=0.0066  |Δm|=1.34e-02
# Iter 444  RMS=0.0066  |Δm|=6.30e-03
# Iter 445  RMS=0.0065  |Δm|=1.26e-02
# Iter 446  RMS=0.0064  |Δm|=1.39e-02
# Iter 447  RMS=0.0076  |Δm|=1.64e-02
# Iter 448  RMS=0.0062  |Δm|=1.62e-02
# Iter 449  RMS=0.0070  |Δm|=6.17e-03
# Iter 450  RMS=0.0070  |Δm|=1.20e-02
# Iter 451  RMS=0.0059  |Δm|=4.79e-03
# Iter 452  RMS=0.0060  |Δm|=1.23e-02
# Iter 453  RMS=0.0059  |Δm|=1.14e-02
# Iter 454  RMS=0.0068  |Δm|=1.51e-02
# Iter 455  RMS=0.0060  |Δm|=4.46e-03
# Iter 456  RMS=0.0066  |Δm|=1.07e-02
# Iter 457  RMS=0.0071  |Δm|=8.69e-03
# Iter 458  RMS=0.0073  |Δm|=1.03e-02
# Iter 459  RMS=0.0063  |Δm|=1.43e-02
# Iter 460  RMS=0.0080  |Δm|=1.07e-02
# Iter 461  RMS=0.0068  |Δm|=8.74e-03
# Iter 462  RMS=0.0064  |Δm|=1.21e-02
# Iter 463  RMS=0.0066  |Δm|=1.43e-02
# Iter 464  RMS=0.0064  |Δm|=4.74e-03
# Iter 465  RMS=0.0067  |Δm|=1.46e-02
# Iter 466  RMS=0.0064  |Δm|=1.14e-02
# Iter 467  RMS=0.0069  |Δm|=1.10e-02
# Iter 468  RMS=0.0066  |Δm|=1.25e-02
# Iter 469  RMS=0.0063  |Δm|=9.07e-03
# Iter 470  RMS=0.0068  |Δm|=1.25e-02
# Iter 471  RMS=0.0068  |Δm|=7.13e-03
# Iter 472  RMS=0.0061  |Δm|=1.50e-02
# Iter 473  RMS=0.0067  |Δm|=1.48e-02
# Iter 474  RMS=0.0060  |Δm|=9.08e-03
# Iter 475  RMS=0.0063  |Δm|=7.84e-03
# Iter 476  RMS=0.0059  |Δm|=6.32e-03
# Iter 477  RMS=0.0063  |Δm|=1.46e-02
# Iter 478  RMS=0.0075  |Δm|=1.32e-02
# Iter 479  RMS=0.0063  |Δm|=5.33e-03
# Iter 480  RMS=0.0065  |Δm|=6.45e-03
# Iter 481  RMS=0.0064  |Δm|=1.01e-02
# Iter 482  RMS=0.0064  |Δm|=9.75e-03
# Iter 483  RMS=0.0061  |Δm|=2.17e-03
# Iter 484  RMS=0.0066  |Δm|=5.74e-03
# Iter 485  RMS=0.0063  |Δm|=9.50e-03
# Iter 486  RMS=0.0066  |Δm|=1.57e-02
# Iter 487  RMS=0.0060  |Δm|=1.15e-02
# Iter 488  RMS=0.0068  |Δm|=1.15e-02
# Iter 489  RMS=0.0061  |Δm|=1.07e-02
# Iter 490  RMS=0.0067  |Δm|=4.60e-03
# Iter 491  RMS=0.0058  |Δm|=1.52e-02
# Iter 492  RMS=0.0068  |Δm|=1.32e-02
# Iter 493  RMS=0.0059  |Δm|=7.48e-03
# Iter 494  RMS=0.0065  |Δm|=1.30e-02
# Iter 495  RMS=0.0067  |Δm|=1.44e-02
# Iter 496  RMS=0.0063  |Δm|=1.04e-02
# Iter 497  RMS=0.0061  |Δm|=8.56e-03
# Iter 498  RMS=0.0063  |Δm|=1.25e-02
# Iter 499  RMS=0.0059  |Δm|=9.02e-03
# Iter 500  RMS=0.0058  |Δm|=8.87e-03
#
# No convergence after 500 iterations.  Best RMS = 0.0052 reached at iter 236.
#
# === True Event ===
# {'x': 1.8, 'y': 2.4, 'z': 3.8, 't0': 0.5}
#
# === Estimated Event ===
# {'x': 1.8111629084406062, 'y': 2.3873524977938194, 'z': 3.79622697807508, 't0': 0.5020379651854141}
